# %% [markdown]
# # <center> Practice Qusetion For String </Center>

# %% [markdown]
# ### Q WAP to input user's first name & print its length.

# %%
name=input("Enter our first name: ")
print("Hello",name,"your name lendth is: ",len(name))
# Out:
# Hello Aniruddh your name lendth is:  8

# %% [markdown]
# ### Q WAP to find the occurrence of '$' in a String.

# %%
str ="Hi, I am a $ and i like $ if you want me the give the$."
print("Number of occurrence of $ is: ",str.count("$"))
# Out:
# 3
