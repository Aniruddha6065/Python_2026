# %% [markdown]
# ### Easy Qusetion
# <small>
# <br> Q5 How do you assign a multi-line string to a variable in Python?
# <br> Q6 What is the built-in function used to find out the data type of a variable?
# <br> Q7: What happens if you try to add a string and an integer together (e.g., "Age: " + 22)? How do you fix it?
# <br>Q8: Which of these variable names is invalid in Python, and why? student_name, 1st_place, _hidden_value, TotalScore.
# <br>Q9: What is the difference between the / operator and the // operator?
# <br>Q10 : How do you create a multiline comment in Python without using the # symbol on every line?
# <br>Q11: What are the three core rules for naming a variable correctly in Python?
# <br>Q12: How can you assign the exact same value (e.g., 10) to three different variables (x, y, and z) in a single line of code?
# <br>Q13: What arithmetic operator do you use to find the remainder of a division in Python?
# <br>Q14: True or False: myVar and myvar are considered the exact same variable in Python. Why?
# <br>Q15: What built-in function would you use to explicitly convert a float like 45.6 into an integer?
# <br>Q16: How can you programmatically view the full list of reserved keywords in Python? (Hint: It requires importing a specific module).</small>

# %% [markdown]
#  ### Advanced Qusetion
#  <small>
# <br>Q17: Python is dynamically typed. What does this mean compared to a statically typed language like C++ or Java?
# <br>Q18: Explain the concept of "immutability." Are integers and strings in Python mutable or immutable?
# <br>Q19: What is type casting, and what is the difference between explicit and implicit type conversion in Python?
# <br>Q20: If a = [1, 2, 3] and b = a, what happens to b if you change a[0] = 99? Why does this happen? (Note: Touches on variables as references)
# <br>Q21: Write a single line of code to swap the values of two variables a and b without using a temporary third variable.
# <br>Q22: What is the exact output of 5 // 2 versus 5 / 2? Explain the difference between these two operators.
# <br>Q23: Explain how Python evaluates Identity Operators (is and is not). How is a is b fundamentally different from a == b?
# <br>Q24: If val1 = True and val2 = False, what is the boolean result of print(not val1 or val2)?
# <br>Q25: Demonstrate how multiple variables can be assigned different values in one single line (e.g., assigning 1, 2, "asg" to variables x, y, z).
# <br>Q27: You execute n = 5 + "t". What specific type of error will Python throw, and how do you fix it?</small>

# %% [markdown]
# ### Tricky / "Gotcha" Questions
# <small>
# <br>Q28: What will be the output of print(0.1 + 0.2 == 0.3)? Explain why.
# <br>Q29: Look at this code: x = 10; y = 10. If you check print(x is y), it returns True. But if you do x = 1000; y = 1000, print(x is y) might return False. Why? (Hint: Integer caching/interning)
# <br>Q30: What is the result of bool("False")? Why is it potentially confusing for beginners?
# <br>Q31: Is class = 10 a valid variable assignment? Why or why not?
# <br>Q32: What happens during execution if you use a standalone string literal (like "This is a note") in your code without assigning it to a variable?
# <br>Q33: What is the difference between the Bitwise left shift operator (<<) and the Assignment left shift operator (<<=)?
# <br>Q34: Why will the variable name 1name throw a syntax error, but name1 will execute perfectly?
# <br>Q35: Python is "dynamically typed." Does this mean you can assign a string to a variable (a = "xyz"), and then assign an integer to that exact same variable (a = 11) in the next line without crashing?</small>

# %% [markdown]
# ### Interview-Style Questions
# <small>
# <br>Q36: Can you explain how Python manages memory for its variables? (Looking for: Reference counting and Garbage Collection).
# <br>Q37: You are reviewing a junior developer's code and they named a variable list = [1, 2, 3]. Why is this a bad practice, and what bugs could it cause later in the script?
# <br>Q38: "Everything in Python is an object." Can you explain what this phrase actually means in the context of basic variables like integers and strings?
# <br>Q39: How does Python handle the concept of "Object Reference" when assigning values to variables in memory?
# <br>Q40: Describe a real-world scenario where a developer must use Explicit Type Conversion because Implicit Type Conversion will fail.
# <br>Q41: What are Bitwise operators (&, |, ^) primarily used for, and how do they evaluate data differently than Logical operators (and, or)?
# <br>Q42: You are explaining Python syntax to someone who only knows Math. How do you explain the difference between the assignment operator (=) and the relational/comparison operator (==)?
# <br>Q43: If you execute a = 10 and b = 10, and then check print(a is b), it returns True. How does Python's memory management make this happen under the hood?
# <br>Q44: Why is it dangerous to use a Python keyword (like def or list) as a variable identifier, and what issues will it cause in a larger program?</small>

# %% [markdown]
# ### Practical Coding Tasks (Write a Program...)
# <small>
# <br>Q45: Write a Python program to input a user's birth year as a string, convert it to an integer, and calculate their exact age today.
# <br>Q46: Write a program to input a two-digit integer (e.g., 45) and print the sum of its digits (e.g., 4 + 5 = 9) using only the floor division (//) and modulus (%) operators.
# <br>Q47: You already know how to swap two variables using a, b = b, a. Write a program to swap two integer variables using only addition (+) and subtraction (-).
# <br>Q48: Write a program that takes a number as input and uses the Bitwise AND operator (&) to determine if the number is even or odd
# <br>Q49: Write a program to calculate the area of a circle. Take the radius as a float input from the user and use  for exponentiation. </small>

# %% [markdown]
# ### Tricky Output Analysis (What will this print?)
#
# <small>**Q50:** Look at the following code. What will be the output, and why?</small>
# ```python
# a = "5"
# b = "7"
# print(a + b)
# ```
#
# <small>**Q51:** What is the exact output of this arithmetic expression, and what rule does Python follow to calculate it?</small>
# ```python
# print(10 - 4 * 2 + 1)
# ```
#
# <small>**Q52:** In your notebook, you demonstrated that `~a` performs a Bitwise NOT. If `a = 10`, the output of `print(~a)` is `-11`. Explain the mathematical formula Python uses to calculate the Bitwise NOT of an integer.</small>
#
# <small>**Q53:** What will the following code output? (Hint: Pay attention to the data types).</small>
# ```python
# x = 5.9
# y = int(x)
# print(y * 2)
# ```
#
# <small>**Q54:** Explain the output of the following Bitwise Left Shift operation:</small>
# ```python
# a = 10
# print(a << 2)
# ```

# %% [markdown]
# ### "Gotcha" Edge Cases (Finding the Bug)
#
# <small>**Q55:** A beginner writes the following code to convert a decimal string to an integer: Why does this throw a `ValueError`, and what is the correct way to typecast this string into an integer?</small>
# ```python
# num = int("10.5")
# print(num)
# ```
#
# <small>**Q56:** Look at the assignment operators below. What is the final value of `x`?</small>
# ```python
# x = 10
# x += 5
# x *= 2
# x -= 10
# print(x)
# ```
#
# <small>**Q58:** Evaluate the following logical expression. Will it print `True` or `False`?</small>
# ```python
# a = True
# b = False
# print(not a and b or a)
# ```
#
# <small>**Q59:** Unassigned string literals can act as multi-line comments. However, what happens to a multi-line string (`""" Hello """`) if it is placed immediately inside a function or class definition? *(Hint: Docstrings)*.
# </small>
